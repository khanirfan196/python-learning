# %%
# Linked list is a Dynamic Data Structure. It has nodes and each node contains data and link to another node.
# It does not require continous memory allocation, meaning that nodes can be located randomly in the memory.
# Types of linked list are: Single, Doubly, and Circular.
# There is no fixed size defined for linked list as it is dynamic. Elements can be removed or added at any node.
# The last node in linked list does not contain any link as there is no other node. It contains null or empty reference.

#      Node
# ----------------
# |       |      |
# | value | link | -----> Next Node ....
# |       |      |
# ----------------
