# %%
import re

# %%
my_string = """How are you?"""

pattern = r"How are you\?"

# %%
# fullmatch() matches the entire string with pattern and returns an object.

my_match = re.fullmatch(pattern, my_string)

print(my_match)
# Out:
# <re.Match object; span=(0, 12), match='How are you?'>

# %%
print(my_match.group())
# Out:
# How are you?
